# %%
import schemdraw
import schemdraw.elements as elm


with schemdraw.Drawing() as d:
    d += ((op := elm.Opamp(leads=True)).label('4', 'vs', fontsize=9, ofst=(-.1, -.2), halign='right', valign='top').label('7', 'vd', fontsize=9, ofst=(-.1, .2), halign='right',
          valign='bottom').label('3', 'in2', fontsize=9, ofst=(-.1, .1), halign='right', valign='bottom').label('6', 'out', fontsize=9, ofst=(-.1, .1), halign='left', valign='bottom').label('2', 'in1', fontsize=9,
          ofst=(-.1, .1), halign='right', valign='bottom'))
    d += (l := elm.Line().right(1.0).at(op.out))
    d += elm.Dot()
    d += elm.Line().up(1).at(op.vd).label('+15 V', 'right')
    d += elm.Dot()
    d += elm.Line().down(1).at(op.vs)
    d += elm.Dot().label('-15 V', 'right')
    d += elm.Line().left(1.0).at(op.in1)
    d += elm.Dot()
    d.push()
    d += elm.Line().up(2)
    d += elm.Dot()
    d.push()
    d += elm.Capacitor2().tox(l.end).label("$C_f$ =0.1 $\mu$F ")
    d += elm.Dot()
    d.pop()
    d += elm.Line().up(2)
    d += elm.Resistor().tox(l.end).label('$R_f$ =100 K$\Omega$')
    d += elm.Line().toy(l.end)
    d.pop()
    d += elm.Resistor().left(5).label('$R_i$ =10 K$\Omega$')
    d += elm.Dot(open=True).label('$V_ { in } $')
    d += elm.Line().right(3).at(l.end)
    d += elm.Dot(open=True).label('$V_ { out } $')
    d += elm.Line().left(1.0).at(op.in2)
    d += elm.Line().down(1.0)
    d += elm.Ground()

    d.draw()
    d.save('int.png')
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:25: SyntaxWarning: invalid escape sequence '\O'
# <>:28: SyntaxWarning: invalid escape sequence '\O'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:25: SyntaxWarning: invalid escape sequence '\O'
# <>:28: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\2734128033.py:21: SyntaxWarning: invalid escape sequence '\m'
#   d += elm.Capacitor2().tox(l.end).label("$C_f$ =0.1 $\mu$F ")
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\2734128033.py:25: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().tox(l.end).label('$R_f$ =100 K$\Omega$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\2734128033.py:28: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().left(5).label('$R_i$ =10 K$\Omega$')

# %%
import schemdraw
import schemdraw.elements as elm


with schemdraw.Drawing() as d:
    d += ((op := elm.Opamp(leads=True)).label('4', 'vs', fontsize=9, ofst=(-.1, -.2), halign='right', valign='top').label('7', 'vd', fontsize=9, ofst=(-.1, .2), halign='right',
          valign='bottom').label('3', 'in2', fontsize=9, ofst=(-.1, .1), halign='right', valign='bottom').label('6', 'out', fontsize=9, ofst=(-.1, .1), halign='left', valign='bottom').label('2', 'in1', fontsize=9,
          ofst=(-.1, .1), halign='right', valign='bottom'))
    d += (l := elm.Line().right(1.0).at(op.out))
    d += elm.Dot()
    d += elm.Line().up(1).at(op.vd).label('+15 V', 'right')
    d += elm.Dot()
    d += elm.Line().down(1).at(op.vs)
    d += elm.Dot().label('-15 V', 'right')
    d += elm.Line().left(1.0).at(op.in1)
    d += elm.Dot()
    d.push()
    d += elm.Line().up(2)
    d += elm.Dot()
    d.push()
    d += elm.Resistor().tox(l.end).label("$R_f$ =100 $k\Omega$ ")
    # d += elm.Dot()
    # d.pop()
    # d += elm.Line().up(2)
    # d += elm.Resistor().tox(l.end).label('$R_f$ =100 K$\Omega$')
    d += elm.Line().toy(l.end)
    d.pop()
    d += elm.Resistor().left(5).label('$R_i$ =10 K$\Omega$')
    d += elm.Dot(open=True).label('$V_ { in } $')
    d += elm.Line().right(3).at(l.end)
    d += elm.Dot(open=True).label('$V_ { out } $')
    d += elm.Line().left(1.0).at(op.in2)
    d += elm.Line().down(1.0)
    d += elm.Ground()

    d.draw()
    d.save('Inv_amp_Schm.png')
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\O'
# <>:28: SyntaxWarning: invalid escape sequence '\O'
# <>:21: SyntaxWarning: invalid escape sequence '\O'
# <>:28: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\3320155896.py:21: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().tox(l.end).label("$R_f$ =100 $k\Omega$ ")
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\3320155896.py:28: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().left(5).label('$R_i$ =10 K$\Omega$')

# %%
import schemdraw
import schemdraw.elements as elm


with schemdraw.Drawing() as d:
    d += ((op := elm.Opamp(leads=True)).label('4', 'vs', fontsize=9, ofst=(-.1, -.2), halign='right', valign='top').label('7', 'vd', fontsize=9, ofst=(-.1, .2), halign='right',
          valign='bottom').label('3', 'in2', fontsize=9, ofst=(-.1, .1), halign='right', valign='bottom').label('6', 'out', fontsize=9, ofst=(-.1, .1), halign='left', valign='bottom').label('2', 'in1', fontsize=9,
          ofst=(-.1, .1), halign='right', valign='bottom'))
    d += (l := elm.Line().right(1.0).at(op.out))
    d += elm.Dot()
    d += elm.Line().up(1).at(op.vd).label('+15 V', 'right')
    d += elm.Dot()
    d += elm.Line().down(1).at(op.vs)
    d += elm.Dot().label('-15 V', 'right')
    d += elm.Line().left(1.0).at(op.in1)
    d += elm.Dot()
    d.push()
    d += elm.Line().up(2)
    d += elm.Dot()
    d.push()
    d += elm.Resistor().tox(l.end).label("$R_f$ =100 $k\Omega$ ")
    # d += elm.Dot()
    # d.pop()
    # d += elm.Line().up(2)
    # d += elm.Resistor().tox(l.end).label('$R_f$ =100 K$\Omega$')
    d += elm.Line().toy(l.end)
    d.pop()
    d.pop()
    d += elm.Line().left(1)
    d += elm.Dot()
    d.push()
    d += elm.Resistor().left(5).label('$R_2$ = 10 K$\Omega$')
    d += elm.Dot(open=True).label('$V_2$')
    d.pop()
    d.push()
    d += elm.Line().up(1.3)
    d += elm.Resistor().left(5).label('$R_1$ = 2 K$\Omega$')
    d += elm.Dot(open=True).label('$V_1$')
    d.pop()
    d += elm.Line().down(1.3)
    d += elm.Resistor().left(5).label('$R_3$ = 20 K$\Omega$')
    d += elm.Dot(open=True).label('$V_3$')
    d += elm.Line().right(3).at(l.end)
    d += elm.Dot(open=True).label('$V_ { out } $')
    d += elm.Line().left(1.0).at(op.in2)
    d += elm.Line().down(1.0)
    d += elm.Ground()

    d.draw()
    d.save('Addr_Schm.png')
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\O'
# <>:32: SyntaxWarning: invalid escape sequence '\O'
# <>:37: SyntaxWarning: invalid escape sequence '\O'
# <>:41: SyntaxWarning: invalid escape sequence '\O'
# <>:21: SyntaxWarning: invalid escape sequence '\O'
# <>:32: SyntaxWarning: invalid escape sequence '\O'
# <>:37: SyntaxWarning: invalid escape sequence '\O'
# <>:41: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\2883494305.py:21: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().tox(l.end).label("$R_f$ =100 $k\Omega$ ")
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\2883494305.py:32: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().left(5).label('$R_2$ = 10 K$\Omega$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\2883494305.py:37: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().left(5).label('$R_1$ = 2 K$\Omega$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_3472\2883494305.py:41: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().left(5).label('$R_3$ = 20 K$\Omega$')

# %%
import os
import schemdraw
import schemdraw.elements as elm


with schemdraw.Drawing() as d:
    d += ((op := elm.Opamp(leads=True)).label('4', 'vs', fontsize=9, ofst=(-.1, -.2), halign='right', valign='top').label('7', 'vd', fontsize=9, ofst=(-.1, .2), halign='right',
          valign='bottom').label('3', 'in2', fontsize=9, ofst=(-.1, .1), halign='right', valign='bottom').label('6', 'out', fontsize=9, ofst=(-.1, .1), halign='left', valign='bottom').label('2', 'in1', fontsize=9,
          ofst=(-.1, .1), halign='right', valign='bottom'))
    d += (l := elm.Line().right(1.0).at(op.out))
    d += elm.Dot()
    d += elm.Line().up(1).at(op.vd).label('+15 V', 'right')
    d += elm.Dot()
    d += elm.Line().down(1).at(op.vs)
    d += elm.Dot().label('-15 V', 'right')
    d += elm.Line().left(1.0).at(op.in1)
    d += elm.Dot()
    d.push()
    d += elm.Line().up(2)
    d.push()
    d += elm.Resistor().tox(l.end).label("$R_f$ =100 $k\Omega$ ")
    d += elm.Line().toy(l.end)
    d.pop()
    d.pop()
    d += elm.Resistor().left(5).label('$R_1$ = 10 K$\Omega$')
    d += elm.Ground().down()
    d += elm.Line().right(3).at(l.end)
    d += elm.Dot(open=True).label('$V_ { out } $')
    d += elm.Dot().at(op.in2)
    d += elm.Resistor().down(2).at(op.in2).label('$10k\Omega$')
    d += elm.Ground()
    d += elm.Capacitor2().left(2).at(op.in2).label('$0.1\mu F$')
    d += elm.Dot()
    d.push()
    d += elm.Resistor().down(2).label('$10k\Omega$')
    d += elm.Ground()
    d.pop()
    d += elm.Capacitor2().left(2).label('$0.1\mu F$')
    d += elm.Dot()
    d.push()
    d += elm.Resistor().down(2).label('$10k\Omega$')
    d += elm.Ground()
    d.pop()
    d += elm.Capacitor2().left(2).label('$0.1\mu F$')
    d += elm.Dot(open=True).label('$V_i $')

    d.draw()
    d.save('High_Pass_Filter.png')
    os.system('shutdown /s /t 0')
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\O'
# <>:24: SyntaxWarning: invalid escape sequence '\O'
# <>:29: SyntaxWarning: invalid escape sequence '\O'
# <>:31: SyntaxWarning: invalid escape sequence '\m'
# <>:34: SyntaxWarning: invalid escape sequence '\O'
# <>:37: SyntaxWarning: invalid escape sequence '\m'
# <>:40: SyntaxWarning: invalid escape sequence '\O'
# <>:43: SyntaxWarning: invalid escape sequence '\m'
# <>:20: SyntaxWarning: invalid escape sequence '\O'
# <>:24: SyntaxWarning: invalid escape sequence '\O'
# <>:29: SyntaxWarning: invalid escape sequence '\O'
# <>:31: SyntaxWarning: invalid escape sequence '\m'
# <>:34: SyntaxWarning: invalid escape sequence '\O'
# <>:37: SyntaxWarning: invalid escape sequence '\m'
# <>:40: SyntaxWarning: invalid escape sequence '\O'
# <>:43: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:20: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().tox(l.end).label("$R_f$ =100 $k\Omega$ ")
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:24: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().left(5).label('$R_1$ = 10 K$\Omega$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:29: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().down(2).at(op.in2).label('$10k\Omega$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:31: SyntaxWarning: invalid escape sequence '\m'
#   d += elm.Capacitor2().left(2).at(op.in2).label('$0.1\mu F$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:34: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().down(2).label('$10k\Omega$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:37: SyntaxWarning: invalid escape sequence '\m'
#   d += elm.Capacitor2().left(2).label('$0.1\mu F$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:40: SyntaxWarning: invalid escape sequence '\O'
#   d += elm.Resistor().down(2).label('$10k\Omega$')
# C:\Users\Rj Avro Biswas\AppData\Local\Temp\ipykernel_696\2835435411.py:43: SyntaxWarning: invalid escape sequence '\m'
#   d += elm.Capacitor2().left(2).label('$0.1\mu F$')
